# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Leer los datos del archivo
data = np.loadtxt('spikes_multipop1.dat')
AVG_data = np.loadtxt('averages_multipop1.dat')

# %%
AVG_data.shape
# Out:
# (2666667, 5)

# %%
raster = data
tiempos = raster[:, 0] 
neuronas = raster[:, 1]

# %%
X_1 = AVG_data[:, 0] 
U_1 = AVG_data[:, 1] 
X_2 = AVG_data[:, 2] 
U_2 = AVG_data[:, 3] 
t = AVG_data[:, 4]

# %%
plt.plot(t,U_1)
plt.plot(t,U_2)

# %%
plt.plot(t,X_1)
plt.plot(t,X_2)

# %%
plt.figure(figsize=(12,15))
plt.subplot(3,1,1)
plt.plot(tiempos, neuronas, 'ko',markersize=0.4, color='steelblue')
plt.xlim(-200,)


plt.show()
# Out:
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_32012\1771068476.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos, neuronas, 'ko',markersize=0.4, color='steelblue')
