# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Columna A

# %%
# Leer los datos del archivo
raster1_colA = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_A\spikes_multipop1.dat')
raster2_colA = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_A\spikes_multipop2.dat')
AVG_data_colA = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_A\averages_multipop1.dat')

# %%
tiempos1_A = raster1_colA[:, 0] 
neuronas1_A = raster1_colA[:, 1] 
tiempos2_A = raster2_colA[:, 0] 
neuronas2_A = raster2_colA[:, 1]

# %%
X_1_A = AVG_data_colA[:, 0] 
U_1_A = AVG_data_colA[:, 1] 
X_2_A = AVG_data_colA[:, 2] 
U_2_A = AVG_data_colA[:, 3] 
t_A = AVG_data_colA[:, 4]

# %%
plt.figure(figsize=(10, 4))

plt.subplot(2, 1, 1)
plt.plot(t_A,X_1_A, linewidth=7, alpha= 0.2)
plt.plot(t_A,X_2_A, linewidth=7, alpha= 0.2)
plt.xlim(-500,)

plt.subplot(2, 1, 2)
plt.plot(t_A,U_1_A, linewidth=7, alpha= 0.2)
plt.plot(t_A,U_2_A, linewidth=7, alpha= 0.2)
plt.xlim(-500,)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.subplot(2, 1, 1)
plt.plot(tiempos1_A, neuronas1_A, 'ko',markersize=1.5, color='steelblue')
plt.ylim(1600,2000)
plt.xlim(-500,)
plt.subplot(2, 1, 2)
plt.plot(tiempos2_A, neuronas2_A, 'ko',markersize=1.5, color='orange')
plt.ylim(1600,2000)
plt.xlim(-500,)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_33936\860732220.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos1_A, neuronas1_A, 'ko',markersize=1.5, color='steelblue')
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_33936\860732220.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos2_A, neuronas2_A, 'ko',markersize=1.5, color='orange')

# %% [markdown]
# # Columna B

# %%
# Leer los datos del archivo
raster1_colB = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_B\spikes_multipop1.dat')
raster2_colB = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_B\spikes_multipop2.dat')
AVG_data_colB = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_B\averages_multipop1.dat')

tiempos1_B = raster1_colB[:, 0] 
neuronas1_B = raster1_colB[:, 1] 
tiempos2_B = raster2_colB[:, 0] 
neuronas2_B = raster2_colB[:, 1] 

X_1_B = AVG_data_colB[:, 0] 
U_1_B = AVG_data_colB[:, 1] 
X_2_B = AVG_data_colB[:, 2] 
U_2_B = AVG_data_colB[:, 3] 
t_B = AVG_data_colB[:, 4]

# %%
plt.figure(figsize=(10, 4))

plt.subplot(2, 1, 1)
plt.plot(t_B,X_1_B, linewidth=7, alpha= 0.2)
plt.plot(t_B,X_2_B, linewidth=7, alpha= 0.2)
plt.xlim(-1000,)

plt.subplot(2, 1, 2)
plt.plot(t_B,U_1_B, linewidth=7, alpha= 0.2)
plt.plot(t_B,U_2_B, linewidth=7, alpha= 0.2)
plt.xlim(-1000,)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))

plt.subplot(2, 1, 1)
plt.plot(tiempos1_B, neuronas1_B, 'ko',markersize=1.9, color='steelblue')
plt.ylim(0,400)
plt.xlim(-500,)
plt.subplot(2, 1, 2)
plt.plot(tiempos2_B, neuronas2_B, 'ko',markersize=1.9, color='orange')
plt.ylim(0,400)
plt.xlim(-500,)
# Out:
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_33936\68645967.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos1_B, neuronas1_B, 'ko',markersize=1.9, color='steelblue')
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_33936\68645967.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos2_B, neuronas2_B, 'ko',markersize=1.9, color='orange')
# (-500.0, 3199.2839000000004)

# %% [markdown]
# # Columna C

# %%
# Leer los datos del archivo
raster1_colC = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_C\spikes_multipop1.dat')
raster2_colC = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_C\spikes_multipop2.dat')
AVG_data_colC = np.loadtxt(r'F:\neuroscience_project\Fig_3_Col_C\averages_multipop1.dat')

tiempos1_C = raster1_colC[:, 0] 
neuronas1_C = raster1_colC[:, 1] 
tiempos2_C = raster2_colC[:, 0] 
neuronas2_C = raster2_colC[:, 1] 

X_1_C = AVG_data_colC[:, 0] 
U_1_C = AVG_data_colC[:, 1] 
X_2_C = AVG_data_colC[:, 2] 
U_2_C = AVG_data_colC[:, 3] 
t_C = AVG_data_colC[:, 4]

# %%
plt.figure(figsize=(10, 4))

plt.subplot(2, 1, 1)
plt.plot(t_C,X_1_C, linewidth=7, alpha= 0.2)
plt.plot(t_C,X_2_C, linewidth=7, alpha= 0.2)
plt.xlim(-500,)

plt.subplot(2, 1, 2)
plt.plot(t_C,U_1_C, linewidth=7, alpha= 0.2)
plt.plot(t_C,U_2_C, linewidth=7, alpha= 0.2)
plt.xlim(-500,)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))

plt.subplot(2, 1, 1)
plt.plot(tiempos1_C, neuronas1_C, 'ko',markersize=1.5, color='steelblue')
#plt.ylim(1600,2000)
plt.xlim(-500,)
plt.subplot(2, 1, 2)
plt.plot(tiempos2_C, neuronas2_C, 'ko',markersize=1.5, color='orange')
#plt.ylim(1600,2000)
plt.xlim(-500,)
# Out:
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_33936\500148941.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos1_C, neuronas1_C, 'ko',markersize=1.5, color='steelblue')
# C:\Users\ocamp\AppData\Local\Temp\ipykernel_33936\500148941.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(tiempos2_C, neuronas2_C, 'ko',markersize=1.5, color='orange')
# (-500.0, 3199.757975)
